# %% [markdown]
# # $k$-means vs GMM

# %% [markdown]
# The objective of this lab is to compare the performance of two clustering algorithms, $k$-means and the EM algorithm for the Gaussian Mixture Model (GMM), on both synthetic and real data.
#
# You will find below Python code for loading data samples either from the Gaussian Mixture Model (GMM) or from the [iris dataset](https://fr.wikipedia.org/wiki/Iris_de_Fisher) and for clustering these data samples by $k$-means and EM on the GMM.

# %% [markdown]
# ## To do

# %% [markdown]
# 1. Compare the performance of $k$-means and Gaussian mixture. Test various parameters for the GMM, and different values of $k$.
# 2. Implement a version of Gaussian mixture where the covariance matrices are diagonal (and thus stored as *vectors*) and test its performance. We refer to this algorithm as GMD (Gaussian Mixture with Diagonal covariance matrices)
# 3. Test these three algorithms ($k$-means, GMM and GMD) on data of your choice.

# %% [markdown]
# ## Import packages

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn import datasets, metrics

# %% [markdown]
# ## Synthetic data

# %%
def gaussian_samples(mean = 0, std_dev = 1, nb_samples = 1):
    '''Gaussian samples
    
    Parameters
    ----------
    mean: float or array of floats, default: 0
        Mean            
    std_dev: float or array of floats, default: 1
        Standard deviation (covariance = SS^T)
    nb_samples: int
        Number of samples
        
    Returns
    -------
    samples: array of floats of shape (nb_samples,dim)
        Gaussian samples (std_dev * normal_samples + mean)
    '''
        
    mean = np.array(mean)
    std_dev = np.array(std_dev)
    try:
        dim = mean.shape[0]
    except:
        dim = 1
    normal_samples = np.random.normal(size = dim * nb_samples).reshape(dim,nb_samples)
    samples = np.array(std_dev).dot(normal_samples) 
    samples += np.array(mean).reshape(dim,1).dot(np.ones((1,nb_samples)))
    return samples.T

# %%
def gmm_samples(means = [0], std_devs = [1], p = None, nb_samples = 1):
    '''Gaussian mixture model samples
    
    Parameters
    ----------
    means: array of floats of shape (nb_modes,dim)
        Means            
    std_dev: array of floats of shape (nb_modes,dim,dim)
        Standard deviations
    p: array of floats of shape (nb_modes)
        Mixing distribution (sums to 1)
    nb_samples: int
        Number of samples
        
    Returns
    -------
    samples: array of floats of shape (nb_samples,dim)
        Gaussian mixture model samples 
    labels: array of integers of shape (nb_samples)
        labels (latent variables)
    '''
    means = np.array(means)
    std_devs = np.array(std_devs)
    nb_labels = means.shape[0]
    try:
        dim = means.shape[1]
    except:
        dim = 1
    labels = np.random.choice(nb_labels, size = nb_samples, p = p)
    samples = np.zeros((nb_samples,dim))
    for j in range(nb_labels):
        nb_samples_j = np.sum(labels == j)
        if nb_samples_j:
            index = np.where(labels == j)[0]
            samples[index] = gaussian_samples(means[j], std_devs[j], nb_samples_j)
    return samples, labels

# %%
def show_samples(samples, labels, features = [0,1], feature_names = None, display_labels = True, title = None, legend_label_names = None):
    '''Display the samples in 2D'''
    if display_labels:
        nb_labels = np.max(labels)
        for j in range(nb_labels + 1):
            nb_samples = np.sum(labels == j)
            if nb_samples:
                index = np.where(labels == j)[0]
                plt.scatter(samples[index,features[0]],samples[index,features[1]])
    else:
        plt.scatter(samples[:,features[0]],samples[:,features[1]],color='gray')
    if feature_names is not None:
        plt.xlabel(feature_names[0])
        plt.ylabel(feature_names[1])
        
    if legend_label_names is not None:
        plt.legend(legend_label_names)
        
    if title is not None:
        plt.title(title)
    plt.axis('equal')
    plt.show()

# %%
means = [[3,2],[-3,2],[0,-4]]
std_devs = [[[1,0],[0,1]],[[1,0],[0,1]],[[2,0],[0,2]]]
p = [0.25,0.25,0.5]

# %%
samples, labels = gmm_samples(means, std_devs, p, 300)

# %%
show_samples(samples, labels)

# %% [markdown]
# ## Real data

# %%
iris = datasets.load_iris()
samples = iris.data  
feature_names = iris.feature_names
true_labels = iris.target
label_names = list(iris.target_names)

# %%
feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
label_names
# Out:
# ['setosa', 'versicolor', 'virginica']

# %%
features = [0,1]
names = [feature_names[i] for i in features]
show_samples(samples, true_labels, features, names)

# %%
features = [2,3]
names = [feature_names[i] for i in features]
show_samples(samples, true_labels, features, names, legend_label_names = label_names)

# %% [markdown]
# ## Metrics

# %%
from sklearn.metrics import adjusted_rand_score as ari
from sklearn.metrics import adjusted_mutual_info_score as ami

# %% [markdown]
# ## k-means

# %%
class KMeans:
    '''k-means algorithm
    
    Parameters
    ----------
    n_clusters: int, default: 8
        Number of clusters.
    
    n_init : int, default: 10
        Number of instances of k-means, each with different initial centers. 
        The output is that of the best instance (in terms of likelihood).
    
    n_iter: int, default: 300
        Number of iterations for each instance of k-means.
        
    algorithm: "random" or "++", default:"++"
        Algorithm for initializing the centers; "++" corresponds to k-means++.
    
    seed: int, default: None
        Seed for the random generation of initial centers.
        
    verbose: boolean, optional
        Verbose mode.
    
    Attributes
    ----------
    labels_: array, shape(n_samples,)
        Label of each sample (cluster index).
        
    centers_ : array, shape(n_clusters, n_features)
        Cluster centers.
        
    inertias_: array, shape(n_clusters,)
        Cluster inertias (sum of square distances).
    '''

    def __init__(self, n_clusters=8, n_init=10, n_iter=300, algorithm='++', seed=None, verbose = False):
        self.n_clusters = n_clusters
        self.n_init = n_init
        self.n_iter = n_iter
        self.algorithm = algorithm
        self.seed = seed
        self.verbose = verbose
        self.labels_ = None
        self.centers_ = None
        self.inertias_ = None
       
    def fit(self, X):
        '''Cluster data X using k-means
    
        Parameters
        ----------
        X: array, shape(n_samples,n_features)
            Data to cluster.
        '''        
        
        def init_centers(self, X):
            if self.algorithm == 'random':
                # random centers 
                samples = np.random.choice(X.shape[0], size = self.n_clusters)
                centers = X[samples]
            else:
                # k-means++
                centers = []
                centers.append(X[np.random.randint(X.shape[0])])
                distance = np.full(X.shape[0], np.inf)
                for j in range(1,self.n_clusters):
                    distance = np.minimum(np.linalg.norm(X - centers[-1], axis=1), distance)
                    p = np.square(distance) / np.sum(np.square(distance))
                    sample = np.random.choice(X.shape[0], p = p)
                    centers.append(X[sample])
            return centers
        
        def compute_centers(self, X, labels):
            centers = []
            for j in range(self.n_clusters):
                index = np.where(labels == j)[0]
                if len(index):
                    centers.append(np.mean(X[index],axis = 0))
                else:
                    # reinit center in case of empty cluster
                    centers.append(X[np.random.choice(X.shape[0])])
            return np.array(centers)

        def compute_distances(self, X, centers):
            distances = []
            for j in range(self.n_clusters):
                distances.append(np.linalg.norm(X - centers[j], axis=1))
            return np.array(distances)
            
        def compute_inertias(self, X, labels, centers):
            inertias = []
            for j in range(self.n_clusters):
                index = np.where(labels == j)[0]
                inertias.append(np.sum(np.square(np.linalg.norm(X[index] - centers[j], axis=1))))
            return np.array(inertias)
    
        def one_kmeans(self, X):
            centers = init_centers(self, X)
            for i in range(self.n_iter):
                centers_old = centers.copy()
                distances = compute_distances(self, X, centers)
                labels = np.argmin(distances, axis=0)  
                centers = compute_centers(self, X, labels)
                if np.array_equal(centers, centers_old):
                    break
            inertias = compute_inertias(self, X, centers, labels)
            return labels, centers, inertias
            
        np.random.seed(self.seed)
        best_inertia = None
        # select the best instance of k-means
        for i in range(self.n_init):
            if self.verbose:
                print("Instance ",i)
            labels, centers, inertias = one_kmeans(self, X)
            inertia = np.sum(inertias)
            if best_inertia is None or inertia < best_inertia:
                best_labels = labels.copy()
                best_centers = centers.copy()
                best_inertias = inertias.copy()
                best_inertia = inertia

        self.labels_ = best_labels
        self.centers_ = best_centers
        self.inertias_ = best_inertias
        return self

# %%
km = KMeans(n_clusters = 3)

# %%
km.fit(samples)

# %%
ari(true_labels, km.labels_)
# Out:
# 0.7163421126838475

# %%
ami(true_labels, km.labels_)
# Out:
# /home/parfait/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:746: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)
# 0.7331180735280008

# %%
show_samples(samples, true_labels, features, names, title = 'Visualisation True Labels', legend_label_names = label_names)
show_samples(samples, km.labels_, features, names, title = 'Visualisation predict Labels', legend_label_names = label_names)

# %% [markdown]
# ## Gaussian mixture

# %%
class GMM:
    '''EM algorithm for the Gaussian mixture model
    
    Parameters
    ----------
    n_clusters: int, default: 8
        Number of clusters.
    
    n_init : int, default: 10
        Number of instances of the algorithm, each with different initial cluster centers. 
        The output is that of the best instance (in terms of likelihood).
    
    n_iter: int, default: 300
        Maximum number of iterations for each instance of the algorithm.
        
    algorithm: "random" or "k-means++", default:"k-means++"
        Algorithm for initializing the means.
    
    seed: int, default: None
        Seed for the random generation of cluster centers.
        
    verbose: boolean, default: True
        Verbose mode.
    
    Attributes
    ----------
    labels_: array, shape(n_samples,)
        Label of each sample (cluster index).

    label_probs_: array, shape(n_samples,n_clusters)
        Probability distribution of labels for each sample.
        
    centers_ : array, shape(n_clusters,n_features)
        Cluster centers.
    '''

    def __init__(self, n_clusters=8, n_init=10, n_iter=300, algorithm='k-means++', seed=None, verbose=True):
        self.n_clusters = n_clusters
        self.n_init = n_init
        self.n_iter = n_iter
        self.algorithm = algorithm
        self.seed = seed
        self.verbose = verbose
        self.labels_ = None
        self.label_probs_ = None
        self.centers_ = None
       
    def fit(self, X):
        '''Cluster data X using EM for the Gaussian mixture model
    
        Parameters
        ----------
        X: array, shape(n_samples,n_features)
            Data to cluster.
        '''        
        
        def init_parameters(self, X):
            # choose initial centers
            if self.algorithm == 'random':
                # random centers
                samples = np.random.choice(X.shape[0], size = self.n_clusters)
                centers = X[samples]
            else:
                # k-means++
                centers = []
                centers.append(X[np.random.randint(X.shape[0])])
                distance = np.full(X.shape[0], np.inf)
                for j in range(1,self.n_clusters):
                    distance = np.minimum(np.linalg.norm(X - centers[-1], axis=1), distance)
                    p = np.square(distance) / np.sum(np.square(distance))
                    sample = np.random.choice(X.shape[0], p = p)
                    centers.append(X[sample])
                
            # estimate the parameters from the induced clusters
            distances = []
            for j in range(self.n_clusters):
                distances.append(np.linalg.norm(X - centers[j], axis=1))
            labels = np.argmin(np.array(distances), axis=0)
            means = []
            covariances = []
            mixing_weights = []
            for j in range(self.n_clusters):
                index = np.where(labels == j)[0]
                mixing_weights.append(len(index))
                if len(index):
                    means.append(np.mean(X[index], axis = 0))
                    covariances.append(np.cov(X[index].T))    
                else:
                    means.append(centers[j])
                    covariances.append(np.eye(X.shape[1]))
            return np.array(means), np.array(covariances), np.array(mixing_weights)

        def compute_label_probs(self, X, means, covariances, mixing_weights):
            label_probs = np.zeros((X.shape[0],self.n_clusters))
            for j in range(self.n_clusters):
                cov = covariances[j]
                try:
                    inv_cov = np.linalg.inv(cov)
                    square_distances = ((X - means[j]).dot(inv_cov) * (X - means[j])).sum(axis = 1) 
                    label_probs[:,j] = np.exp(-square_distances / 2) / np.sqrt(np.linalg.det(cov))
                except:
                    if self.verbose:
                        print("Warning: Singular covariance matrix")
                    square_distances = np.square(X - means[j]).sum(axis = 1) 
                    label_probs[:,j] = np.exp(-square_distances / 2) 
            label_probs = label_probs * mixing_weights
            label_probs = (label_probs.T / label_probs.sum(axis = 1)).T
            return label_probs    
                        
        def compute_parameters(self, X, label_probs):
            mixing_weights = label_probs.sum(axis = 0)
            means = (X.T.dot(label_probs) / mixing_weights).T
            covariances = []
            for j in range(self.n_clusters):
                Y = (X - means[j]).T * label_probs[:,j]
                covariances.append(Y.dot(X - means[j]) / mixing_weights[j])
            return means, covariances, mixing_weights
        
        def compute_log_likelihood(self, X, means, covariances, mixing_weights):
            likelihoods = np.zeros((X.shape[0],self.n_clusters))
            total_weight = mixing_weights.sum()
            for j in range(self.n_clusters):
                cov = covariances[j]
                try:
                    inv_cov = np.linalg.inv(cov)
                    square_distances = ((X - means[j]).dot(inv_cov) * (X - means[j])).sum(axis = 1) 
                    likelihoods[:,j] = mixing_weights[j] / total_weight * np.exp(-square_distances / 2) / np.sqrt(np.linalg.det(cov))
                except:
                    if self.verbose:
                        print("Warning: Singular covariance matrix")
                    square_distances = np.square(X - means[j]).sum(axis = 1) 
                    likelihoods[:,j] = mixing_weights[j] / total_weight * np.exp(-square_distances / 2) 
            return np.log(likelihoods.sum(axis = 1)).sum()
    
        def single_run_EM(self, X):
            means, covariances, mixing_weights = init_parameters(self, X)
            labels = -np.ones(X.shape[0])
            for i in range(self.n_iter):    
                # Expectation
                label_probs = compute_label_probs(self, X, means, covariances, mixing_weights)              
                if np.array_equal(labels, label_probs.argmax(axis = 1)):
                    break
                else:
                # Maximization
                    means, covariances, mixing_weights = compute_parameters(self, X, label_probs)
                    labels = label_probs.argmax(axis = 1)
            return label_probs, means, covariances, mixing_weights
            
        np.random.seed(self.seed)
        best_loglikelihood = None
        # select the best instance of EM
        for i in range(self.n_init):
            if self.verbose:
                print("Instance ",i)               
            label_probs, means, covariances, mixing_weights = single_run_EM(self, X)
            loglikelihood = compute_log_likelihood(self, X, means, covariances, mixing_weights)
            if best_loglikelihood is None or loglikelihood > best_loglikelihood:
                best_loglikelihood = loglikelihood
                best_label_probs = label_probs
                best_labels = label_probs.argmax(axis = 1)
                best_centers = means
        self.label_probs_ = best_label_probs
        self.labels_ = best_labels
        self.centers_ = best_centers
        return self

# %%
gmm = GMM(n_clusters = 3)

# %%
gmm.fit(samples)
# Out:
# Instance  0
# Instance  1
# Instance  2
# Instance  3
# Instance  4
# Instance  5
# Instance  6
# Instance  7
# Instance  8
# Instance  9

# %%
ari(true_labels, gmm.labels_)
# Out:
# 0.9038742317748124

# %%
ami(true_labels, gmm.labels_)
# Out:
# /home/parfait/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:746: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)
# 0.8970537476260634

# %%
show_samples(samples, true_labels, features, names, title = 'Visualisation True Labels', legend_label_names = label_names)
show_samples(samples, gmm.labels_, features, names, title = 'Visualisation predict Labels', legend_label_names = label_names)

# %%
ari_array_gmm = []
ami_array_gmm = []
for k in range(3,8):
    gmm = GMM(n_clusters = k)
    gmm.fit(samples)
    ari_array_gmm.append(ari(true_labels, gmm.labels_))
    ami_array_gmm.append(ami(true_labels, gmm.labels_))
# Out:
# Instance  0
# Instance  1
# Instance  2
# Instance  3
# Instance  4
# Instance  5
# Instance  6
# Instance  7
# Instance  8
# Instance  9
# Instance  0
# Instance  1
# /home/parfait/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:746: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /home/parfait/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:100: RuntimeWarning: invalid value encountered in sqrt
# /home/parfait/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py:2093: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /home/parfait/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:746: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)
# Instance  2
# Instance  3
# Instance  4
# Instance  5
# Instance  6
# Instance  7
# Instance  8
# Instance  9
# Instance  0
# Instance  1
# Instance  2
# Instance  3
# Instance  4
# Instance  5
# Instance  6
# Warning: Singular covariance matrix
# /home/parfait/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:100: RuntimeWarning: invalid value encountered in sqrt
# /home/parfait/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py:2093: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /home/parfait/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:746: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /home/parfait/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:87: RuntimeWarning: Degrees of freedom <= 0 for slice
# /home/parfait/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:2451: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /home/parfait/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:2451: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# /home/parfait/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py:2093: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /home/parfait/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:100: RuntimeWarning: invalid value encountered in sqrt
# Instance  7
# Instance  8
# Instance  9
# Instance  0
# Instance  1
# Instance  2
# Instance  3
# Instance  4
# Instance  5
# Warning: Singular covariance matrix
# Instance  6
# Instance  7
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Instance  8
# Instance  9
# Instance  0
# Instance  1
# Instance  2
# Instance  3
# Instance  4
# Instance  5
# Instance  6
# /home/parfait/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:746: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /home/parfait/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:100: RuntimeWarning: invalid value encountered in sqrt
# /home/parfait/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py:2093: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /home/parfait/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:87: RuntimeWarning: Degrees of freedom <= 0 for slice
# /home/parfait/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:2451: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /home/parfait/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:2451: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# Instance  7
# Instance  8
# Instance  9
# /home/parfait/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:746: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)

# %%
ari_array_km = []
ami_array_km = []
for k in range(3,8):
    km = KMeans(n_clusters = k)
    km.fit(samples)
    ari_array_km.append(ari(true_labels, km.labels_))
    ami_array_km.append(ami(true_labels, km.labels_))
# Out:
# /home/parfait/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:746: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /home/parfait/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:746: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /home/parfait/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:746: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /home/parfait/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:746: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)
# /home/parfait/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:746: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)

# %%
x=np.arange(3,8)
plt.figure(figsize=(12,8))
p1=plt.plot(x,ari_array_gmm,marker='o')
p2=plt.plot(x,ami_array_gmm,marker='v')
p3=plt.plot(x,ari_array_km,marker='o')
p4=plt.plot(x,ami_array_km,marker='v')
plt.title("Précisions Classifications GMM vs KM")
plt.xlabel('Variations k')
plt.ylabel('Précision')
plt.grid()
plt.legend(["Adjusted Rand Score GMM", "Adjusted Mutual Info Score GMM","Adjusted Rand Score KM","Adjusted Mutual Info Score KM"])
plt.show()

# %% [markdown]
# ## Gaussian mixture with diagonal covariance matrices

# %%
class GMD:
    '''EM algorithm for the Gaussian mixture model with diagonal covariance matrices
    
    Parameters
    ----------
    n_clusters: int, default: 8
        Number of clusters.
    
    n_init : int, default: 10
        Number of instances of the algorithm, each with different initial cluster centers. 
        The output is that of the best instance (in terms of likelihood).
    
    n_iter: int, default: 300
        Maximum number of iterations for each instance of the algorithm.
        
    algorithm: "random" or "k-means++", default:"k-means++"
        Algorithm for initializing the means.
    
    seed: int, default: None
        Seed for the random generation of cluster centers.
        
    verbose: boolean, default: True
        Verbose mode.
    
    Attributes
    ----------
    labels_: array, shape(n_samples,)
        Label of each sample (cluster index).

    label_probs_: array, shape(n_samples,n_clusters)
        Probability distribution of labels for each sample.
        
    centers_ : array, shape(n_clusters,n_features)
        Cluster centers.
    '''

    def __init__(self, n_clusters=8, n_init=10, n_iter=300, algorithm='k-means++', seed=None, verbose=True):
        self.n_clusters = n_clusters
        self.n_init = n_init
        self.n_iter = n_iter
        self.algorithm = algorithm
        self.seed = seed
        self.verbose = verbose
        self.labels_ = None
        self.label_probs_ = None
        self.centers_ = None
       
    def fit(self, X):
        '''Cluster data X using EM for the Gaussian mixture model with diagonal covariance matrices
    
        Parameters
        ----------
        X: array, shape(n_samples,n_features)
            Data to cluster.
        '''                
        def init_parameters(self, X):
            # choose initial centers
            if self.algorithm == 'random':
                # random centers
                samples = np.random.choice(X.shape[0], size = self.n_clusters)
                centers = X[samples]
            else:
                # k-means++
                centers = []
                centers.append(X[np.random.randint(X.shape[0])])
                distance = np.full(X.shape[0], np.inf)
                for j in range(1,self.n_clusters):
                    distance = np.minimum(np.linalg.norm(X - centers[-1], axis=1), distance)
                    p = np.square(distance) / np.sum(np.square(distance))
                    sample = np.random.choice(X.shape[0], p = p)
                    centers.append(X[sample])
                
            # estimate the parameters from the induced clusters
            distances = []
            for j in range(self.n_clusters):
                distances.append(np.linalg.norm(X - centers[j], axis=1))
            labels = np.argmin(np.array(distances), axis=0)
            means = []
            covariances = []
            mixing_weights = []
            for j in range(self.n_clusters):
                index = np.where(labels == j)[0]
                mixing_weights.append(len(index))
                if len(index):
                    means.append(np.mean(X[index], axis = 0))
                    covariances.append(np.cov(X[index].T))    
                else:
                    means.append(centers[j])
                    covariances.append(np.eye(X.shape[1]))
            return np.array(means), np.array(covariances), np.array(mixing_weights)

        def compute_label_probs(self, X, means, covariances, mixing_weights):
            label_probs = np.zeros((X.shape[0],self.n_clusters))
            for j in range(self.n_clusters):
                cov = np.diag(covariances[j])
                print(cov)
                try:
                    inv_cov = np.linalg.inv(cov)
                    square_distances = ((X - means[j]).dot(inv_cov) * (X - means[j])).sum(axis = 1) 
                    label_probs[:,j] = np.exp(-square_distances / 2) / np.sqrt(np.linalg.det(cov))
                except:
                    if self.verbose:
                        print("Warning: Singular covariance matrix")
                    square_distances = np.square(X - means[j]).sum(axis = 1) 
                    label_probs[:,j] = np.exp(-square_distances / 2) 
            label_probs = label_probs * mixing_weights
            label_probs = (label_probs.T / label_probs.sum(axis = 1)).T
            return label_probs    
                        
        def compute_parameters(self, X, label_probs):
            mixing_weights = label_probs.sum(axis = 0)
            means = (X.T.dot(label_probs) / mixing_weights).T
            covariances = []
            for j in range(self.n_clusters):
                Y = (X - means[j]).T * label_probs[:,j]
                covariances.append(Y.dot(X - means[j]) / mixing_weights[j])
            return means, covariances, mixing_weights
        
        def compute_log_likelihood(self, X, means, covariances, mixing_weights):
            likelihoods = np.zeros((X.shape[0],self.n_clusters))
            total_weight = mixing_weights.sum()
            for j in range(self.n_clusters):
                cov = np.diag(covariances[j])
                try:
                    inv_cov = np.linalg.inv(cov)
                    square_distances = ((X - means[j]).dot(inv_cov) * (X - means[j])).sum(axis = 1) 
                    likelihoods[:,j] = mixing_weights[j] / total_weight * np.exp(-square_distances / 2) / np.sqrt(np.linalg.det(cov))
                except:
                    if self.verbose:
                        print("Warning: Singular covariance matrix")
                    square_distances = np.square(X - means[j]).sum(axis = 1) 
                    likelihoods[:,j] = mixing_weights[j] / total_weight * np.exp(-square_distances / 2) 
            return np.log(likelihoods.sum(axis = 1)).sum()
    
        def single_run_EM(self, X):
            means, covariances, mixing_weights = init_parameters(self, X)
            labels = -np.ones(X.shape[0])
            for i in range(self.n_iter):    
                # Expectation
                label_probs = compute_label_probs(self, X, means, covariances, mixing_weights)              
                if np.array_equal(labels, label_probs.argmax(axis = 1)):
                    break
                else:
                # Maximization
                    means, covariances, mixing_weights = compute_parameters(self, X, label_probs)
                    labels = label_probs.argmax(axis = 1)
            return label_probs, means, covariances, mixing_weights
            
        np.random.seed(self.seed)
        best_loglikelihood = None
        # select the best instance of EM
        for i in range(self.n_init):
            if self.verbose:
                print("Instance ",i)               
            label_probs, means, covariances, mixing_weights = single_run_EM(self, X)
            loglikelihood = compute_log_likelihood(self, X, means, covariances, mixing_weights)
            if best_loglikelihood is None or loglikelihood > best_loglikelihood:
                best_loglikelihood = loglikelihood
                best_label_probs = label_probs
                best_labels = label_probs.argmax(axis = 1)
                best_centers = means
        self.label_probs_ = best_label_probs
        self.labels_ = best_labels
        self.centers_ = best_centers
        return self

# %%
ari_array_gmd = []
ami_array_gmd = []
for k in range(3,8):
    gmd = GMD(n_clusters = k)
    gmd.fit(samples)
    ari_array_gmd.append(ari(true_labels, gmd.labels_))
    ami_array_gmd.append(ami(true_labels, gmd.labels_))
# Out:
# Instance  0
# [0.43934949 0.11072323 0.6815798  0.18042828]
# Warning: Singular covariance matrix
# [0.05115079 0.07407407 0.03063492 0.00439153]
# Warning: Singular covariance matrix
# [0.05229437 0.08251082 0.02599567 0.01569264]
# Warning: Singular covariance matrix
# [0.42041049 0.10764072 0.64814322 0.17603123]
# Warning: Singular covariance matrix
# [0.11642498 0.1631574  0.15702825 0.03408685]
# Warning: Singular covariance matrix
# [0.12170014 0.16811448 0.14485957 0.03225732]
# Warning: Singular covariance matrix
# [0.41647862 0.10692685 0.63913353 0.17484038]
# Warning: Singular covariance matrix
# [0.12154786 0.17623749 0.19111587 0.0399688 ]
# Warning: Singular covariance matrix
# [0.12296809 0.17605663 0.18122316 0.03826461]
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Instance

# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Instance  8
# [0.24834225 0.08242424 0.21875223 0.05639929]
# Warning: Singular covariance matrix
# [0.12424898 0.1436898  0.03015918 0.01110612]
# Warning: Singular covariance matrix
# [0.19378846 0.09733333 0.18378846 0.04202564]
# Warning: Singular covariance matrix
# [0.14413846 0.07058462 0.06481538 0.06984615]
# Warning: Singular covariance matrix
# [0.36123814 0.1012705  0.45715576 0.11830123]
# Warning: Singular covariance matrix
# [0.12338981 0.1576876  0.11576301 0.02621052]
# Warning: Singular covariance matrix
# [0.26348347 0.09983143 0.46683912 0.13016238]
# Warning: Singular covariance matrix
# [0.28048007 0.08793781 0.42380407 0.15027041]
# Warning: Singular covariance matrix
# [0.39199842 0.10475308 0.52438054 0.1330427 ]
# Warning: Singular covariance matrix
# [0.12308036 0.16379479 0.14029739 0.03073833]
# Warning: Singular covariance matrix
# [0.28545132 0.09852593 0.46941942 0.14040959]
# Warning: Singular covariance matrix
# [0.31981142 0.09306642 0.49101754 0.16038869]
# Warning: Singular covariance matrix
# [0.40631232 0.10621963 0.55538626 0.14006712]
# Warning: Singular covariance matrix
# [0.1229718  0.1673637  0.15476087 0.03335896]
# Warning: Singular covariance matrix
# [0.30009517 0.09882195 0.4848853  0.14705601]
# Warning: Singular covariance matrix
# [0.33758586 0.09568585 0.52008557 0.1638163 ]
# Warning: Singular covariance matrix
# [0.41420673 0.10703595 0.57242579 0.14400835]
# Warning: Singular covariance matrix
# [0.12291914 0.1693796  0.16291629 0.03482101]
# Warning: Singular covariance matrix
# [0.31009204 0.09921632 0.49767566 0.15123687]
# Warning: Singular covariance matrix
# [0.34697163 0.09716458 0.53544582 0.16547744]
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Instance  9
# [0.15416807 0.07727731 0.16769748 0.03255462]
# Warning: Singular covariance matrix
# [0.16319549 0.06772556 0.2060589  0.11219925]
# Warning: Singular covariance matrix
# [0.12424898 0.1436898  0.03015918 0.01110612]
# Warning: Singular covariance matrix
# [0.05428571 0.22410714 0.08785714 0.04857143]
# Warning: Singular covariance matrix
# [0.25821386 0.10157817 0.47459803 0.12380845]
# Warning: Singular covariance matrix
# [0.32244294 0.0894671  0.46971246 0.15375822]
# Warning: Singular covariance matrix
# [0.12351248 0.15789964 0.11799735 0.02656385]
# Warning: Singular covariance matrix
# [0.2922037  0.15906311 0.34737515 0.06467714]
# Warning: Singular covariance matrix
# [0.28138858 0.10021284 0.47269093 0.13470455]
# Warning: Singular covariance matrix
# [0.35772001 0.09538919 0.52916408 0.16079332]
# Warning: Singular covariance matrix
# [0.12315393 0.16416621 0.14261588 0.03110574]
# Warning: Singular covariance matrix
# [0.35454672 0.14707349 0.43066484 0.08030039]
# Warning: Singular covariance matrix
# [0.29598368 0.10016515 0.48427012 0.14190231]
# Warning: Singular covariance matrix
# [0.37268412 0.09793082 0.55536279 0.16404264]
# Warning: Singular covariance matrix
# [0.12301086 0.16778146 0.15695549 0.03371889]
# Warning: Singular covariance matrix
# [0.3806449  0.14211639 0.47033081 0.08907668]
# Warning: Singular covariance matrix
# [0.30612876 0.1004001  0.49594218 0.1467645 ]
# [0.1229167  0.16987614 0.16500214 0.03518102]
# Warning: Singular covariance matrix
# [0.40606443 0.1316985  0.51283424 0.10284587]
# Warning: Singular covariance matrix
# [0.36497109 0.09811669 0.55577698 0.16730013]
# Warning: Singular covariance matrix
# [0.3109579  0.10091312 0.50338145 0.1489346 ]
# Warning: Singular covariance matrix
# [0.40907376 0.1035407  0.58785079 0.15760165]
# Warning: Singular covariance matrix
# [0.1228677  0.17117341 0.17006872 0.03609284]
# Warning: Singular covariance matrix
# [0.41203838 0.13109271 0.52374942 0.10550089]
# Warning: Singular covariance matrix
# [0.36956013 0.09897316 0.56390979 0.16826828]
# Warning: Singular covariance matrix
# [0.31664734 0.10099989 0.51049751 0.15167053]
# Warning: Singular covariance matrix
# [0.41191751 0.10400087 0.59338263 0.15859002]
# Warning: Singular covariance matrix
# [0.12283293 0.17201017 0.17329215 0.03667271]
# Warning: Singular covariance matrix
# [0.41531496 0.13091036 0.52975389 0.10689262]
# Warning: Singular covariance matrix
# [0.37216294 0.09951021 0.5688249  0.16890707]
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Instance  1
# [0.0896732  0.05676471 0.11088235 0.07647059]
# Warning: Singular covariance matrix
# [0.12424898 0.1436898  0.03015918 0.01110612]
# Warning: Singular covariance matrix
# [0.09936759 0.06474308 0.1372332  0.03027668]
# Warning: Singular covariance matrix
# [0.09739418 0.04470899 0.08111111 0.04638889]
# Warning: Singular covariance matrix
# [0.2495914  0.08862366 0.20789247 0.0571828 ]
# Warning: Singular covariance matrix
# [0.27422128 0.08856592 0.41706417 0.15130576]
# Warning: Singular covariance matrix
# [0.12368928 0.15771855 0.11862104 0.02661894]
# Warning: Singular covariance matrix
# [0.24923896 0.10804525 0.53072893 0.12416095]
# Warning: Singular covariance matrix
# [0.27388485 0.08707196 0.42165524 0.14620127]
# Warning: Singular covariance matrix
# [0.36688281 0.10380718 0.46000894 0.11547684]
# Warning: Singular covariance matrix
# [0.31444439 0.09338852 0.48611048 0.15978444]
# Warning: Singular covariance matrix
# [0.12319227 0.1635545  0.14016508 0.03065558]
# Warning: Singular covariance matrix
# [0.27291954 0.10288506 0.48330542 0.1294509 ]
# Warning: Singular covariance matrix
# [0.31214119 0.09344143 0.48495112 0.15830476]
# Warning: Singular covariance matrix
# [0.39623768 0.10672686 0.52594799 0.13033704]
# Warning: Singular covariance matrix
# [0.33233967 0.09586978 0.51556725 0.16305257]
# Warning: Singular covariance matrix
# [0.12301106 0.16720474 0.15440836 0.03327267]
# Warning: Singular covariance matrix
# /home/parfait/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:746: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)
# [0.28762139 0.10129511 0.48066112 0.13663879]
# Warning: Singular covariance matrix
# [0.3295306  0.0959505  0.51292979 0.16227017]
# Warning: Singular covariance matrix
# [0.40974834 0.10787986 0.55572253 0.13728431]
# Warning: Singular covariance matrix
# [0.34178859 0.09728754 0.53091526 0.16476186]
# Warning: Singular covariance matrix
# [0.12293179 0.16935086 0.16289533 0.0348083 ]
# Warning: Singular covariance matrix
# [0.2983656  0.10091327 0.4887992  0.14251238]
# Warning: Singular covariance matrix
# [0.33898705 0.09733844 0.52808938 0.16413599]
# Warning: Singular covariance matrix
# [0.41722823 0.10853717 0.572017   0.14114996]
# Warning: Singular covariance matrix
# [0.12276501 0.17305563 0.17704928 0.03736351]
# Warning: Singular covariance matrix
# [0.35146442 0.09966532 0.54997952 0.16679492]
# Warning: Singular covariance matrix
# [0.12276275 0.17311698 0.17728755 0.03740596]
# Warning: Singular covariance matrix
# ...
# [0.12278328 0.17285559 0.17638466 0.03723755]
# Warning: Singular covariance matrix
# [0.34935617 0.09967246 0.54771041 0.16623247]
# Warning: Singular covariance matrix
# [0.12278336 0.17285532 0.17638283 0.03723723]
# Warning: Singular covariance matrix
# [0.30901362 0.10232375 0.50430218 0.14591252]
# Warning: Singular covariance matrix
# [0.43231709 0.11564509 0.58185996 0.13344588]
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Instance  5
# [0.06527778 0.19611111 0.10194444 0.05611111]
# Warning: Singular covariance matrix
# [0.05919355 0.06903226 0.03007056 0.01125   ]
# Warning: Singular covariance matrix
# [0.16478979 0.07900901 0.10780781 0.08618619]
# Warning: Singular covariance matrix
# [0.09952381 0.03571429 0.07285714 0.00238095]
# Warning: Singular covariance matrix
# [0.11769559 0.08134424 0.11331437 0.05317923]
# Warning: Singular covariance matrix
# [0.05441176 0.07281046 0.02810458 0.01035948]
# Warning: Singular covariance matrix
# [0.02444444 0.02       0.04194444 0.01277778]
# Warning: Singular covariance matrix
# [0.30876964 0.15034121 0.36475136 0.06976147]
# Warning: Singular covariance matrix
# [0.11865486 0.15231272 0.11964451 0.02670274]
# Warning: Singular covariance matrix
# [0.32828679 0.0901584  0.45413895 0.1464965 ]
# Warning: Singular covariance matrix
# [0.23794395 0.1448505  0.80761527 0.14816583]
# Warning: Singular covariance matrix
# [0.26711844 0.09460368 0.43753181 0.13579205]
# Warning: Singular covariance matrix
# [0.12358746 0.15674424 0.11004398 0.02540191]
# Warning: Singular covariance matrix
# [0.29645746 0.08746432 0.45754446 0.1489442 ]
# Warning: Singular covariance matrix
# [0.36636728 0.13947378 0.44598305 0.08599799]
# Warning: Singular covariance matrix
# [0.12251741 0.16344182 0.14280951 0.03109688]
# Warning: Singular covariance matrix
# [0.36587411 0.09612184 0.52667067 0.15566514]
# Warning: Singular covariance matrix
# [0.25513461 0.12235215 0.61863612 0.12862914]
# Warning: Singular covariance matrix
# [0.29469777 0.09682342 0.47358135 0.14751166]
# Warning: Singular covariance matrix
# [0.1239168  0.16384042 0.13669572 0.03009974]
# Warning: Singular covariance matrix
# [0.32882847 0.09368774 0.50533679 0.16146879]
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Instance  6
# [0.0374359  0.05641026 0.01807692 0.00333333]
# Warning: Singular covariance matrix
# [0.07126667 0.05916667 0.1075     0.09443333]
# Warning: Singular covariance matrix
# [0.027 0.058 0.037 0.01 ]
# Warning: Singular covariance matrix
# [0.04290909 0.07672727 0.01618182 0.04690909]
# Warning: Singular covariance matrix
# [0.21863531 0.09215447 0.17173635 0.03344948]
# Warning: Singular covariance matrix
# [0.23188312 0.09212121 0.17707792 0.05967532]
# Warning: Singular covariance matrix
# [0.04660282 0.05708669 0.0316129  0.01350806]
# Warning: Singular covariance matrix
# [0.11522394 0.14996599 0.11287463 0.02522518]
# Warning: Singular covariance matrix
# [0.12284608 0.17151588 0.17120869 0.03630976]
# Warning: Singular covariance matrix
# [0.35472819 0.09865219 0.54962081 0.16725793]
# Warning: Singular covariance matrix
# [0.32375358 0.09981017 0.51651425 0.15687072]
# Warning: Singular covariance matrix
# [0.42781808 0.11379023 0.57715243 0.13457935]
# Warning: Singular covariance matrix
# [0.12284047 0.17152818 0.17130324 0.03632628]
# Warning: Singular covariance matrix
# [0.12281996 0.17206507 0.17341336 0.03670337]
# Warning: Singular covariance matrix
# [0.37825396 0.09971709 0.57256964 0.16803239]
# Warning: Singular covariance matrix
# [0.12282241 0.17205899 0.17336858 0.03669553]
# Warning: Singular covariance matrix
# [0.35672371 0.09904718 0.55315491 0.16761915]
# Warning: Singular covariance matrix
# [0.32756774 0.09998679 0.52171678 0.15824411]
# Warning: Singular covariance matrix
# [0.43003797 0.11403075 0.58149805 0.1354623 ]
# Warning: Singular covariance matrix
# [0.12282101 0.17206274 0.17339556 0.03670026]
# Warning: Singular covariance matrix
# [0.12280578 0.1724396  0.17485444 0.0369614 ]
# Warning: Singular covariance matrix
# [0.37889474 0.09994185 0.57457967 0.16846634]
# Warning: Singular covariance matrix
# [0.1228064  0.17243778 0.17484174 0.03695917]
# Warning: Singular covariance matrix
# [0.35788514 0.0993193  0.55538949 0.16785008]
# Warning: Singular covariance matrix
# [0.33049907 0.10011398 0.52571332 0.1592966 ]
# Warning: Singular covariance matrix
# [0.43152625 0.11426662 0.58417268 0.13588749]
# Warning: Singular covariance matrix
# [0.12280604 0.17243888 0.17484932 0.0369605 ]
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Instance  7
# [0.04619883 0.06251462 0.02619883 0.00333333]
# Warning: Singular covariance matrix
# [0.12606452 0.0571828  0.09178495 0.08356989]
# Warning: Singular covariance matrix
# [0.1337037  0.08259259 0.07874644 0.06789174]
# Warning: Singular covariance matrix
# [0.01583333 0.06666667 0.04333333 0.00916667]
# Warning: Singular covariance matrix
# [0.03642857 0.20982143 0.08785714 0.03357143]
# Warning: Singular covariance matrix
# [0.03549858 0.04293447 0.02487179 0.01507123]
# Warning: Singular covariance matrix
# [0.14552585 0.09893939 0.18937611 0.04574866]
# Warning: Singular covariance matrix
# [0.1162527  0.14921275 0.10888657 0.02459146]
# Warning: Singular covariance matrix
# [0.33312489 0.09138154 0.44375651 0.13740585]
# Warning: Singular covariance matrix
# [0.281205   0.08916207 0.43234308 0.1487609 ]
# Warning: Singular covariance matrix
# [0.12380494 0.15603247 0.0854083  0.02121342]
# Warning: Singular covariance matrix
# [0.29961774 0.15037902 0.35762897 0.06756438]
# Warning: Singular covariance matrix
# [0.12161829 0.15429833 0.11666305 0.02652339]
# Warning: Singular covariance matrix
# [0.26352002 0.10225284 0.49421198 0.13176408]
# Warning: Singular covariance matrix
# [0.12203292 0.16284728 0.14105005 0.03081844]
# Warning: Singular covariance matrix
# [0.37352836 0.09775757 0.52351164 0.14863325]
# Warning: Singular covariance matrix
# [0.31671966 0.09366181 0.49128706 0.15993684]
# Warning: Singular covariance matrix
# [0.12455007 0.16338791 0.12860019 0.0287645 ]
# Warning: Singular covariance matrix
# [0.36301193 0.13956097 0.44108223 0.08479657]
# Warning: Singular covariance matrix
# [0.12324189 0.16372071 0.13931038 0.03058953]
# Warning: Singular covariance matrix
# [0.28441892 0.0996906  0.47488462 0.13846835]
# Warning: Singular covariance matrix
# [0.12274733 0.16743784 0.1561282  0.03359322]
# Warning: Singular covariance matrix
# [0.39033875 0.10043205 0.55624304 0.15373931]
# Warning: Singular covariance matrix
# [0.3338072  0.09606142 0.51840622 0.16349573]
# Warning: Singular covariance matrix
# [0.12338607 0.16723602 0.15136324 0.03277978]
# Warning: Singular covariance matrix
# [0.38925029 0.13496491 0.48324447 0.09489561]
# Warning: Singular covariance matrix
# [0.12303336 0.16749414 0.15479125 0.03337079]
# Warning: Singular covariance matrix
# [0.29848754 0.0995921  0.48588383 0.14505906]
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Instance  8
# [0.03576923 0.01474359 0.18641026 0.10564103]
# Warning: Singular covariance matrix
# [0.12424898 0.1436898  0.03015918 0.01110612]
# Warning: Singular covariance matrix
# [0.033 0.022 0.102 0.037]
# Warning: Singular covariance matrix
# [0.10576923 0.05089744 0.10269231 0.02192308]
# Warning: Singular covariance matrix
# [0.10465465 0.04861862 0.16231231 0.11947447]
# Warning: Singular covariance matrix
# [0.26474359 0.07025641 0.10435897 0.04589744]
# Warning: Singular covariance matrix
# [0.05339181 0.07877193 0.16467836 0.08497076]
# Warning: Singular covariance matrix
# [0.31140218 0.08775344 0.47939578 0.15457642]
# Warning: Singular covariance matrix
# [0.12358598 0.15856952 0.12119217 0.02710526]
# Warning: Singular covariance matrix
# [0.3051921  0.13918028 0.36957326 0.06902671]
# Warning: Singular covariance matrix
# [0.24606551 0.12091834 0.62769691 0.12839866]
# Warning: Singular covariance matrix
# [0.27240385 0.09119922 0.43599066 0.14917997]
# Warning: Singular covariance matrix
# [0.36201042 0.11378888 0.42772913 0.10251954]
# Warning: Singular covariance matrix
# [0.31007156 0.08942747 0.45947675 0.15456149]
# Warning: Singular covariance matrix
# [0.34744398 0.09427207 0.52218394 0.16203096]
# Warning: Singular covariance matrix
# [0.1231419  0.16440221 0.14320529 0.03121046]
# Warning: Singular covariance matrix
# [0.36448725 0.1379782  0.44398235 0.08554059]
# Warning: Singular covariance matrix
# [0.26568415 0.10958605 0.52505491 0.12477924]
# Warning: Singular covariance matrix
# [0.30657515 0.09540454 0.48541931 0.156249  ]
# Warning: Singular covariance matrix
# [0.39846244 0.11437699 0.50972946 0.11724037]
# Warning: Singular covariance matrix
# [0.34630127 0.09427177 0.5184518  0.16228086]
# Warning: Singular covariance matrix
# [0.36230621 0.09681231 0.54531244 0.1650083 ]
# Warning: Singular covariance matrix
# [0.12297175 0.1678801  0.15686448 0.0337183 ]
# Warning: Singular covariance matrix
# [0.38884489 0.13454785 0.4824359  0.09502999]
# Warning: Singular covariance matrix
# [0.27942019 0.10473587 0.49144668 0.12899466]
# Warning: Singular covariance matrix
# [0.32211783 0.09716191 0.5088324  0.15984431]
# Warning: Singular covariance matrix
# [0.41324989 0.11477746 0.54164693 0.12405397]
# Warning: Singular covariance matrix
# [0.36177319 0.09678272 0.54453384 0.1651093 ]
# Warning: Singular covariance matrix
# [0.3701218  0.09819412 0.55865866 0.16662381]
# Warning: Singular covariance matrix
# [0.12289418 0.16993441 0.16498708 0.03518919]
# Warning: Singular covariance matrix
# [0.40150148 0.13243891 0.50451094 0.10069586]
# Warning: Singular covariance matrix
# [0.29038461 0.10316464 0.48942178 0.13523878]
# Warning: Singular covariance matrix
# [0.3310205  0.09819912 0.52228336 0.16188433]
# Warning: Singular covariance matrix
# [0.42101578 0.11512948 0.55793913 0.12774904]
# Warning: Singular covariance matrix
# [0.36971595 0.09817013 0.55830562 0.1666803 ]
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Instance  9
# [0.1378125  0.06193548 0.17708669 0.03103831]
# Warning: Singular covariance matrix
# [0.06516129 0.08       0.0286996  0.0136996 ]
# Warning: Singular covariance matrix
# [0.05565934 0.05016484 0.04681319 0.01692308]
# Warning: Singular covariance matrix
# [0.04251634 0.06535948 0.02575163 0.00352941]
# Warning: Singular covariance matrix
# [0.03897436 0.06923077 0.01525641 0.04589744]
# Warning: Singular covariance matrix
# [0.25742063 0.08878571 0.21437302 0.06884921]
# Warning: Singular covariance matrix
# [0.295 0.022 0.187 0.053]
# Warning: Singular covariance matrix
# [0.25684116 0.09997116 0.47095234 0.12782573]
# Warning: Singular covariance matrix
# [0.12275515 0.15497532 0.1140752  0.02604735]
# Warning: Singular covariance matrix
# [0.27918829 0.08606414 0.42590502 0.14520122]
# Warning: Singular covariance matrix
# [0.11631404 0.14997907 0.1126645  0.02520384]
# Warning: Singular covariance matrix
# [0.27020068 0.08778164 0.40597617 0.15201154]
# Warning: Singular covariance matrix
# [0.36150804 0.10020548 0.46291073 0.12180124]
# Warning: Singular covariance matrix
# [0.25823459 0.10207629 0.45527359 0.11681636]
# Warning: Singular covariance matrix
# [0.28179769 0.09878466 0.4668854  0.13775849]
# Warning: Singular covariance matrix
# [0.12346344 0.16339024 0.13761461 0.03026703]
# Warning: Singular covariance matrix
# [0.31922199 0.09293018 0.49048805 0.15919599]
# Warning: Singular covariance matrix
# [0.12205238 0.16262488 0.14097774 0.03077247]
# Warning: Singular covariance matrix
# [0.31510263 0.09307465 0.48464099 0.15969289]
# Warning: Singular covariance matrix
# [0.3913231  0.10364066 0.52879176 0.13638835]
# Warning: Singular covariance matrix
# [0.27885698 0.1001764  0.46942546 0.13388484]
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# Warning: Singular covariance matrix
# /home/parfait/anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/supervised.py:746: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)

# %%
x=np.arange(3,8)
plt.figure(figsize=(12,8))
p1=plt.plot(x,ari_array_gmd,marker='o')
p2=plt.plot(x,ami_array_gmd,marker='v')
p3=plt.plot(x,ari_array_km,marker='o')
p4=plt.plot(x,ami_array_km,marker='v')
plt.title("Précisions Classifications GMD vs KM")
plt.xlabel('Variations k')
plt.ylabel('Précision')
plt.grid()
plt.legend(["Adjusted Rand Score GMD", "Adjusted Mutual Info Score GMD","Adjusted Rand Score KM","Adjusted Mutual Info Score KM"])
plt.show()
